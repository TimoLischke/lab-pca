# %% [markdown]
# # PCA Lab
# In this notebook, you will work with Principal Component Analysis (PCA) using a customer retail dataset.

# %% [markdown]
# ## Step 1: Load our customer data

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('retail_customer_data.csv')

# Display the first few rows of the dataset
df.head(20)
# Out:
#     CustomerID  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0            1   56                  89                      47
# 1            2   69                  91                      86
# 2            3   46                  46                      23
# 3            4   32                  28                      66
# 4            5   60                  81                      27
# 5            6   25                  56                       2
# 6            7   38                 116                      90
# 7            8   56                  70                      17
# 8            9   36                  63                      33
# 9           10   40                  43                       9
# 10          11   28                  98                      43
# 11          12   28                  78                      48
# 12          13   41                  51                      39
# 13          14   53                 115                      93
# 14          15   57                 107                      42
# 15          16   41                  71                      26
# 16          17   20                  81                      99
# 17          18   39                  77                      50
# 18          19   19                  71                      25
# 19          20   41                  31                      24
#
#     Number of Purchases  Years as Customer
# 0                    17                  2
# 1                     7                  2
# 2                     5                  2
# 3                    12                  3
# 4                    17                  2
# 5                    13                  4
# 6                     3                  9
# 7                     9                  6
# 8                    17                  1
# 9                    17                  8
# 10                   16                  7
# 11                   13                  3
# 12                   19                  1
# 13                   17                  5
# 14                    4                  4
# 15                   12                  8
# 16                    9                  1
# 17                   19                  1
# 18                   12                  4
# 19                    9                  8

# %%
# drop CustomerID column
df_sel = df.drop(columns=["CustomerID"])
df_sel
# Out:
#      Age  Annual Income (k$)  Spending Score (1-100)  Number of Purchases  \
# 0     56                  89                      47                   17
# 1     69                  91                      86                    7
# 2     46                  46                      23                    5
# 3     32                  28                      66                   12
# 4     60                  81                      27                   17
# ..   ...                 ...                     ...                  ...
# 195   69                  77                      99                   19
# 196   30                  86                      49                    7
# 197   58                  65                      99                    6
# 198   20                  43                      36                    2
# 199   56                  51                      82                    6
#
#      Years as Customer
# 0                    2
# 1                    2
# 2                    2
# 3                    3
# 4                    2
# ..                 ...
# 195                  4
# 196                  9
# 197                  9
# 198                  2
# 199                  8
#
# [200 rows x 5 columns]

# %% [markdown]
# ## Step 2: Standardize the Data
# Standardizing the data is a crucial step before applying PCA. This will ensure each feature has a mean of 0 and a standard deviation of 1.

# %%
from sklearn.preprocessing import StandardScaler

# Standardize the data
scaler = StandardScaler()
scaled_data = scaler.fit_transform(df_sel)
scaled_df = pd.DataFrame(scaled_data, columns=df_sel.columns)
scaled_df.head(20)
# Out:
#          Age  Annual Income (k$)  Spending Score (1-100)  Number of Purchases  \
# 0   0.843704            0.655650               -0.112121             1.237061
# 1   1.715924            0.723173                1.208939            -0.572831
# 2   0.172767           -0.796098               -0.925081            -0.934809
# 3  -0.766547           -1.403806                0.531473             0.332115
# 4   1.112080            0.385557               -0.789587             1.237061
# 5  -1.236203           -0.458482               -1.636420             0.513104
# 6  -0.363984            1.567212                1.344432            -1.296787
# 7   0.843704            0.014180               -1.128321            -0.210852
# 8  -0.498171           -0.222151               -0.586347             1.237061
# 9  -0.229796           -0.897382               -1.399307             1.237061
# 10 -1.034922            0.959504               -0.247614             1.056071
# 11 -1.034922            0.284272               -0.078247             0.513104
# 12 -0.162702           -0.627290               -0.383107             1.599039
# 13  0.642423            1.533450                1.446052             1.237061
# 14  0.910798            1.263358               -0.281487            -1.115798
# 15 -0.162702            0.047941               -0.823461             0.332115
# 16 -1.571672            0.385557                1.649292            -0.210852
# 17 -0.296890            0.250511               -0.010501             1.599039
# 18 -1.638766            0.047941               -0.857334             0.332115
# 19 -0.162702           -1.302521               -0.891207            -0.210852
#
#     Years as Customer
# 0           -1.148346
# 1           -1.148346
# 2           -1.148346
# 3           -0.761697
# 4           -1.148346
# 5           -0.375049
# 6            1.558193
# 7            0.398248
# 8           -1.534994
# 9            1.171544
# 10           0.784896
# 11          -0.761697
# 12          -1.534994
# 13           0.011599
# 14          -0.375049
# 15           1.171544
# 16          -1.534994
# 17          -1.534994
# 18          -0.375049
# 19           1.171544

# %% [markdown]
# ## Step 3: Apply PCA to Reduce Dimensionality
# Now, apply PCA to reduce the dimensionality of the dataset. Let's start by reducing it to 2 components.

# %%
from sklearn.decomposition import PCA

# Apply PCA with 2 components
pca = PCA(n_components=2)
pca_result = pca.fit_transform(scaled_df)

explained_variance = pca.explained_variance_ratio_
print("Explained variance ratio:", explained_variance)
# Out:
# Explained variance ratio: [0.2440217  0.21346818]

# %% [markdown]
# ### Exercise 1: Analyze the Explained Variance
# What do the explained variance ratios tell you about the data? How much of the original data's variance is captured by the first two principal components? Write your observations below.

# %%
# PC1 holds 24.4% of the variance od the data, while PC2 holds only 21.3% of the variance of the data.
# The remaining 54.3% of variance are lost!

# %% [markdown]
# ## Step 4: Visualize the PCA Results
# Let's visualize the dataset in the new PCA-transformed 2D space.

# %%
import matplotlib.pyplot as plt

# Plot the PCA results
plt.figure(figsize=(8, 6))
plt.scatter(pca_result[:, 0], pca_result[:, 1])
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA on Random Dataset')
plt.show()

# %% [markdown]
# ### Exercise 2: Interpretation of the Plot
# Interpret the scatter plot. Do you notice any clusters or patterns? What might this indicate about the underlying structure of the data?

# %%
# The individual dots are rather evenly scattered in the plot.
# There are hardly clusters or patterns noticable.
# Using just two PCs are too few to cluster the data properly.
# The data apparently is very random and does not contain groups or clusters of customers with specific features.

# %% [markdown]
# ## Step 5: Experiment with Different Number of Components
# Experiment with applying PCA with a different number of components (e.g., 3 or 4). Observe how the cumulative explained variance changes.

# %%
# Apply PCA with 4 components
pca = PCA(n_components=4)
pca_result = pca.fit_transform(scaled_df)

cumulative_variance = pca.explained_variance_ratio_.cumsum()
print("Cumulative explained variance:", cumulative_variance)

# Plot cumulative explained variance
plt.figure(figsize=(8, 6))
plt.plot(range(1, 5), cumulative_variance, marker='o')
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('Cumulative Explained Variance by PCA Components')
plt.show()
# Out:
# Cumulative explained variance: [0.2440217  0.45748989 0.64825509 0.83133738]

# %%
# 3D Scatter Plot
fig = plt.figure(figsize=(12, 6))
ax = fig.add_subplot(111, projection='3d')
sc = ax.scatter(pca_result[:, 0], pca_result[:, 1], pca_result[:, 2], c=pca_result[:, 3], cmap='viridis', alpha=0.8)
ax.set_xlabel("PC1")
ax.set_ylabel("PC2")
ax.set_zlabel("PC3")
plt.colorbar(sc, label="PC4 Intensity")
plt.title("3D PCA Visualization")
plt.show()

# %% [markdown]
# ### Exercise 3: Reflection on PCA Components
# Reflect on how the cumulative explained variance changes as more components are added. What does this suggest about the number of components needed to adequately represent the data?

# %%
# When 4 PCs are used over 83% of the variance of the data is covered.
# This should improve the clustering tremendously!

# %% [markdown]
# ## Conclusion
# In this lab, you applied PCA to a new retail customer dataset. You learned how to standardize data, apply PCA, and interpret the results. Notice how PCA can be useful in reducing dimensionality while retaining as much information as possible.
